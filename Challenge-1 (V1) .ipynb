# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %%
train_df = pd.read_csv("../input/train.csv")
print("Shape of Training Set: {}".format(train_df.shape))
test_df = pd.read_csv("../input/test.csv")
print("Shape of Test Set: {}".format(test_df.shape))
# Out:
# Shape of Training Set: (4459, 4993)
# Shape of Test Set: (49342, 4992)

# %%
print("Train Data Information: ")
train_df.info()
print("/n Test Data Information: /n")
# test_df.info()
# Out:
# Train Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Columns: 4993 entries, ID to 9fc776466
# dtypes: float64(1845), int64(3147), object(1)
# memory usage: 169.9+ MB
# /n Test Data Information: /n

# %%
# Description of the datasets
train_df.describe()
# Out:
#              target     48df886f9      ...          7e293fbaf     9fc776466
# count  4.459000e+03  4.459000e+03      ...       4.459000e+03  4.459000e+03
# mean   5.944923e+06  1.465493e+04      ...       9.219960e+04  2.279100e+05
# std    8.234312e+06  3.893298e+05      ...       1.635993e+06  1.811139e+06
# min    3.000000e+04  0.000000e+00      ...       0.000000e+00  0.000000e+00
# 25%    6.000000e+05  0.000000e+00      ...       0.000000e+00  0.000000e+00
# 50%    2.260000e+06  0.000000e+00      ...       0.000000e+00  0.000000e+00
# 75%    8.000000e+06  0.000000e+00      ...       0.000000e+00  0.000000e+00
# max    4.000000e+07  2.000000e+07      ...       6.176800e+07  4.320000e+07
#
# [8 rows x 4992 columns]

# %%
train_df.head()
# Out:
#           ID      target  48df886f9    ...      fb36b89d9  7e293fbaf  9fc776466
# 0  000d6aaf2  38000000.0        0.0    ...              0          0          0
# 1  000fbd867    600000.0        0.0    ...              0          0          0
# 2  0027d6b71  10000000.0        0.0    ...              0          0          0
# 3  0028cbf45   2000000.0        0.0    ...              0          0          0
# 4  002a68644  14400000.0        0.0    ...              0          0          0
#
# [5 rows x 4993 columns]

# %%
train_df.shape
# Out:
# (4459, 4993)

# %%
dtypes_train = train_df.dtypes
dtypes_train[:5]
# Out:
# ID            object
# target       float64
# 48df886f9    float64
# 0deb4b6a8      int64
# 34b15f335    float64
# dtype: object

# %% [markdown]
# As we need to focus on the 'target' feature. We are going to plot the target features in orer to find any outliear by plotting it on the graph[](http://)

# %%
train_df.target.describe()
# Out:
# count    4.459000e+03
# mean     5.944923e+06
# std      8.234312e+06
# min      3.000000e+04
# 25%      6.000000e+05
# 50%      2.260000e+06
# 75%      8.000000e+06
# max      4.000000e+07
# Name: target, dtype: float64

# %%
plt.figure(figsize = (15,8))
plt.scatter(range(train_df.shape[0]), np.sort(train_df.target))
plt.xlabel("Target", fontsize = 12)
plt.ylabel("Value", fontsize = 12)
plt.title("Distribution", fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.distplot(train_df['target'], bins=50)

# %% [markdown]
# Here, from the above chart it can be concluded that the distribution of target variable is skewed i.e. left-skewed. In order to deal with this problem of skewness, normalisation is generally used.
# For normalisation, we are converting the value of target variable in log form (log tranformation)

# %%
plt.figure(figsize=(15,5))
sns.distplot(np.log1p(train_df['target']), bins=50)
